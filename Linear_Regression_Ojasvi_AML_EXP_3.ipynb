# %% [markdown]
# <a href="https://colab.research.google.com/github/ojasvi-1705/Applied-Machine-Learning/blob/main/Linear_Regression_Ojasvi_AML_EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DOWNLOAD AND READ Salary_Data.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('Salary_Data.csv')
# Out:
#      <input type="file" id="files-5a3b9957-52ea-4b24-ab8a-08d47c1f8a3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a3b9957-52ea-4b24-ab8a-08d47c1f8a3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (30, 2)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# LINEAR REGRESSION

# %%
# SPLIT DATA in X and Y
x = df.iloc[:,0].values.reshape(-1,1)
y = df.iloc[:,1].values

# %%
# TRAIN- TEST SPLIT
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# TRAIN MODEL
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# MODEL FIT

# %%
# EQUATION OF BEST FIT LINE
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 9423.815323030976
# Intercept (c): 25321.583011776813

# %%
#PREDICT VALUES
y_pred = model.predict(x_test)

# %%
# PLOT BEST FIT LINE
plt.scatter(x_train, y_train)
plt.plot(x_train, model.predict(x_train), color="red")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Best Fit Line")
plt.show()

# %% [markdown]
# EVALUATE MEAN SQUARED ERROR AND MEAN ABSOLUTE ERROR

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
MSE = mean_squared_error(y_test, y_pred)
MAE = mean_absolute_error(y_test, y_pred)

print("Mean Squared Error (MSE):", MSE)
print("Mean Absolute Error (MAE):", MAE)
# Out:
# Mean Squared Error (MSE): 49830096.85590839
# Mean Absolute Error (MAE): 6286.453830757749
